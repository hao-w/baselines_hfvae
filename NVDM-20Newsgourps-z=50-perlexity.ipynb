# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from torch.nn import Parameter
import sys
from torchvision import datasets, transforms
import pickle
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.datasets import fetch_20newsgroups
import os
import random
import time
sys.path.append('/home/hao/Research/probtorch/')
from probtorch.util import expand_inputs
import probtorch
print('probtorch:', probtorch.__version__, 
      'torch:', torch.__version__, 
      'cuda:', torch.cuda.is_available())
# Out:
# probtorch: 0.0+5a2c637 torch: 0.4.0a0+265e1a9 cuda: True

# %%
# model parameters
NUM_HIDDEN = 500
NUM_LATENTS = 50
VOCABULARY_SIZE = 2000
NUM_DOCS = 11268

# training parameters
NUM_SAMPLES = 1
BATCH_SIZE = 500
NUM_EPOCHS = 1000
LEARNING_RATE = 5e-5
ALPHA = 1.0
BETA = (1.0, 1.0, 0.0, 1.0, 0.0)
BIAS = (NUM_DOCS - 1) / (BATCH_SIZE - 1) 
CUDA = torch.cuda.is_available()

RESTORE = False

# %% [markdown]
# ## dataset

# %%
def shuffler(train_dataset):
    index = np.arange(train_dataset.shape[0])
    np.random.shuffle(index)
    return train_dataset[index, :]

def NUM_ITERS(train_dataset):
    remainder = train_dataset.shape[0] % BATCH_SIZE
    if remainder == 0:
        num_iters = int(train_dataset.shape[0] / BATCH_SIZE)
    else:
        num_iters = int(((train_dataset.shape[0] - remainder) / BATCH_SIZE) + 1)
    return num_iters

# %%
def data_set(data_url):
    """process data input."""
    data = []
    word_count = []
    fin = open(data_url)
    while True:
        line = fin.readline()
        if not line:
            break
        id_freqs = line.split()
        doc = {}
        count = 0
        for id_freq in id_freqs[1:]:
            items = id_freq.split(':')
            # python starts from 0
            doc[int(items[0])-1] = int(items[1])
            count += int(items[1])
        if count > 0:
            data.append(doc)
            word_count.append(count)
    fin.close()
    return data, word_count

def load_voca(filename):
    fp = open(filename)
    voca = dict()
    value = 0
    for line in fp.readlines():
        line = line.strip().split(' ')
        value += 1
        voca[line[0]] = value
    return voca

def convert_np(train_dataset, voca):
    train_dataset_array = np.zeros((len(train_dataset), len(voca)))
    for i in range(len(train_dataset)):
        for k, v in train_dataset[i].items():
            train_dataset_array[i, k] = v
    return train_dataset_array

# %%
train_dataset, train_count = data_set('/home/hao/Research/nips2018/nvdm/20News_train.txt')
voca = load_voca('/home/hao/Research/nips2018/nvdm/20News_voca.txt')
train_dataset = convert_np(train_dataset, voca)
len(train_dataset), len(voca)
# Out:
# (11268, 2000)

# %% [markdown]
# ## encoder

# %%
class Encoder(nn.Module):
    def __init__(self, vocabulary_size=VOCABULARY_SIZE,
                       num_hidden=NUM_HIDDEN,
                       num_latents=NUM_LATENTS):
        super(self.__class__, self).__init__()
        self.enc_hidden = nn.Sequential(
            nn.Linear(vocabulary_size, num_hidden),
            nn.ReLU())
        self.latent_mean = nn.Sequential(
            nn.Linear(num_hidden, num_latents))
        self.latent_log_std = nn.Sequential(
            nn.Linear(num_hidden, num_latents))
        
    @expand_inputs
    def forward(self, documents, num_samples=None):
        q = probtorch.Trace()
        hidden = self.enc_hidden(documents)
        latents_mean = self.latent_mean(hidden)
        latents_std = torch.exp(self.latent_log_std(hidden))
        q.normal(latents_mean, latents_std, name='z')
        return q

# %% [markdown]
# ## decoder

# %%
class Decoder(nn.Module):
    def __init__(self, vocabulary_size=VOCABULARY_SIZE,
                       num_hidden=NUM_HIDDEN,
                       num_latents=NUM_LATENTS,
                       num_samples=NUM_SAMPLES,
                       batch_size=BATCH_SIZE):
        super(self.__class__, self).__init__()
        self.dec_hidden = nn.Sequential(
            nn.Linear(num_latents, num_hidden),
            nn.ReLU())
        self.dec_document = nn.Sequential(
                           nn.Linear(num_hidden, vocabulary_size),
                           nn.LogSoftmax(dim=-1))
        self.prior_mean = torch.zeros((num_samples, batch_size, num_latents)).cuda()
        self.prior_cov = torch.ones((num_samples, batch_size, num_latents)).cuda()

    def forward(self, documents, q=None, num_samples=None):
        p = probtorch.Trace()
        latents = p.normal(self.prior_mean, self.prior_cov, value=q['z'], name='z')   
        hidden = self.dec_hidden(latents)
        documents_recon = self.dec_document(hidden)
        p.loss(cross_entropy, documents_recon, documents, name='documents')
        return p

# %%
def cross_entropy(x_recon, x):
    return - (x_recon * x).sum(-1)

# %% [markdown]
# ## initialization

# %%
def initialize():
    enc = Encoder()
    dec = Decoder()
    if CUDA:
        enc.cuda()
        dec.cuda()
    optimizer =  torch.optim.Adam(list(enc.parameters())+list(dec.parameters()),lr=LEARNING_RATE)    
    return enc, dec, optimizer

# %%
def elbo(q, p):
    if NUM_SAMPLES is None:
        ave_elbo = probtorch.objectives.montecarlo.elbo(q, p, sample_dim=None, batch_dim=0, beta=1.0,)
        elbos = probtorch.objectives.montecarlo.elbo(q, p, sample_dim=None, batch_dim=0, beta=1.0, reduce=False)
        return ave_elbo, elbos
    else:
        ave_elbo = probtorch.objectives.montecarlo.elbo(q, p, sample_dim=0, batch_dim=1, beta=1.0)
        elbos = probtorch.objectives.montecarlo.elbo(q, p, sample_dim=0, batch_dim=1, beta=1.0, reduce=False)
        return ave_elbo, elbos

# %%
# def elbo(q, p):
#     if NUM_SAMPLES is None:
#         ave_elbo = probtorch.objectives.marginal.elbo(q, p, sample_dim=None, batch_dim=0, alpha=ALPHA, bias=BIAS)
#         return ave_elbo
#     else:
#         ave_elbo = probtorch.objectives.marginal.elbo(q, p, sample_dim=0, batch_dim=1, alpha=ALPHA, bias=BIAS)
#         return ave_elbo

# %%
# def elbo(q, p):
#     if NUM_SAMPLES is None:
#         ave_elbo = probtorch.objectives.marginal.elbo(q, p, sample_dim=None, batch_dim=0, beta=BETA, bias=BIAS)
#         elbos = probtorch.objectives.marginal.elbo(q, p, sample_dim=None, batch_dim=0, beta=BETA, bias=BIAS, reduce=False)
#         return ave_elbo, elbos
#     else:
#         ave_elbo = probtorch.objectives.marginal.elbo(q, p, sample_dim=0, batch_dim=1, beta=BETA, bias=BIAS)
#         elbos = probtorch.objectives.marginal.elbo(q, p, sample_dim=0, batch_dim=1, beta=BETA, bias=BIAS, reduce=False)
#         return ave_elbo, elbos

# %%
def train(enc, dec, optimizer):
    if RESTORE == False:
        num_iters = NUM_ITERS(train_dataset)
        elbos_list = []
        perplexities_list = []
        for epoch in range(NUM_EPOCHS):
            time_start = time.time()
            train_dataset_shuffled = shuffler(train_dataset)
            epoch_elbo = 0.0
            perplexity = 0.0
            N = 0.0
            for i in range(num_iters):
                documents = train_dataset_shuffled[i * BATCH_SIZE : (i + 1) * BATCH_SIZE, :]
                if documents.shape[0] == BATCH_SIZE:
                    N += 1
                    documents = torch.FloatTensor(documents)
                    N_d = documents.sum(-1)
                    if CUDA:
                        documents = documents.cuda()
                    optimizer.zero_grad()
                    q = enc(documents, num_samples=NUM_SAMPLES)
                    p = dec(documents, q, num_samples=NUM_SAMPLES)
                    ave_elbo, elbos = elbo(q, p)
                    loss = -ave_elbo
                    loss.backward()
                    optimizer.step()
                    if CUDA:
                        loss = loss.cpu()
                        elbos = elbos.cpu()
                        epoch_elbo += -loss.data.numpy()
                    perplexity += torch.mul(elbos, (1 / N_d)).sum()
                    
            average_epoch_elbo = epoch_elbo / N
            elbos_list.append(average_epoch_elbo)
            perplexity = torch.exp((-1 / (N * BATCH_SIZE)) * perplexity)
            perplexities_list.append(perplexity)
            
            time_end = time.time()
            print('Epoch : %d, ELBO : %f (%ds), Perplexity : %f' % (epoch+1, average_epoch_elbo, time_end - time_start, perplexity))
        return elbos_list, perplexities_list

# %%
enc, dec, optimizer = initialize()
elbos_list, perplexities_list = train(enc, dec, optimizer)
# Out:
# Epoch : 1, ELBO : -766.879367 (0s), Perplexity : 2000.549561
# Epoch : 2, ELBO : -752.261000 (0s), Perplexity : 1865.950073
# Epoch : 3, ELBO : -745.280118 (0s), Perplexity : 1756.040161
# Epoch : 4, ELBO : -744.908231 (0s), Perplexity : 1662.083618
# Epoch : 5, ELBO : -732.717521 (0s), Perplexity : 1587.514771
# Epoch : 6, ELBO : -735.136366 (0s), Perplexity : 1526.008789
# Epoch : 7, ELBO : -732.432506 (0s), Perplexity : 1476.679321
# Epoch : 8, ELBO : -725.018668 (0s), Perplexity : 1438.075317
# Epoch : 9, ELBO : -723.221308 (0s), Perplexity : 1403.983521
# Epoch : 10, ELBO : -720.649925 (0s), Perplexity : 1375.562256
# Epoch : 11, ELBO : -719.668815 (0s), Perplexity : 1353.605347
# Epoch : 12, ELBO : -719.599307 (0s), Perplexity : 1334.398804
# Epoch : 13, ELBO : -718.848378 (0s), Perplexity : 1318.392944
# Epoch : 14, ELBO : -716.145716 (0s), Perplexity : 1306.251953
# Epoch : 15, ELBO : -713.943481 (0s), Perplexity : 1296.810547
# Epoch : 16, ELBO : -717.371471 (0s), Perplexity : 1288.367798
# Epoch : 17, ELBO : -712.540991 (0s), Perplexity : 1281.774414
# Epoch : 18, ELBO : -710.315771 (0s), Perplexity : 1275.212891
# Epoch : 19, ELBO : -711.063027 (0s), Perplexity : 1270.635620
# Epoch : 20, ELBO : -713.715626 (0s), Perplexity : 1268.091675
# Epoch : 21, ELBO : -711.365196 (0s), Perplexity : 1263.641846
# Epoch : 22, ELBO : -708.751792 (0s), Perplexity : 1260.651978
# Epoch : 23, ELBO : -709.707855 (0s), Perplexity : 1257.707397
# Epoch : 24, ELBO : -708.688435 (0s), Perplexity : 1253.405884
# Epoch : 25, ELBO : -704.449818 (0s), Perplexity : 1253.161987
# Epoch : 26, ELBO : -711.954826 (0s), Perplexity : 1250.762085
# Epoch : 27, ELBO : -706.895139 (0s), Perplexity : 1248.091919
# Epoch : 28, ELBO : -710.018166 (0s), Perplexity : 1245.380981
# Epoch : 29, ELBO : -708.272583 (0s), Perplexity : 1244.227661
# Epoch : 30, ELBO : -707.487943 (0s), Perplexity : 1241.843140
# Epoch : 31, ELBO : -706.875397 (0s), Perplexity : 1240.272583
# Epoch : 32, ELBO : -708.309240 (0s), Perplexity : 1236.705566
# Epoch : 33, ELBO : -703.724587 (0s), Perplexity : 1235.494995
# Epoch : 34, ELBO : -704.597973 (0s), Perplexity : 1234.240723
# Epoch : 35, ELBO : -700.449735 (0s), Perplexity : 1232.252563
# Epoch : 36, ELBO : -705.071289 (0s), Perplexity : 1229.466431
# Epoch : 37, ELBO : -702.310960 (0s), Perplexity : 1227.900391
# Epoch : 38, ELBO : -703.459267 (0s), Perplexity : 1222.543579
# Epoch : 39, ELBO : -703.413352 (0s), Perplexity : 1222.966309
# Epoch : 40, ELBO : -700.462155 (0s), Perplexity : 1218.872314
# Epoch : 41, ELBO : -697.617642 (0s), Perplexity : 1216.527100
# Epoch : 42, ELBO : -702.942130 (0s), Perplexity : 1215.256226
# Epoch : 43, ELBO : -698.818395 (0s), Perplexity : 1212.242065
# Epoch : 44, ELBO : -700.845312 (0s), Perplexity : 1209.405518
# Epoch : 45, ELBO : -702.563399 (0s), Perplexity : 1206.795288
# Epoch : 46, ELBO : -696.824560 (0s), Perplexity : 1202.612793
# Epoch : 47, ELBO : -694.036388 (0s), Perplexity : 1202.072754
# Epoch : 48, ELBO : -701.093284 (0s), Perplexity : 1199.109497
# Epoch : 49, ELBO : -697.677610 (0s), Perplexity : 1197.609009
# Epoch : 50, ELBO : -699.652954 (0s), Perplexity : 1192.873901
# Epoch : 51, ELBO : -697.088448 (0s), Perplexity : 1189.534668
# Epoch : 52, ELBO : -693.864638 (0s), Perplexity : 1188.836548
# Epoch : 53, ELBO : -697.883603 (0s), Perplexity : 1184.278564
# Epoch : 54, ELBO : -695.649750 (0s), Perplexity : 1183.098877
# Epoch : 55, ELBO : -694.958915 (0s), Perplexity : 1178.758423
# Epoch : 56, ELBO : -690.867096 (0s), Perplexity : 1174.633301
# Epoch : 57, ELBO : -691.725708 (0s), Perplexity : 1172.307251
# Epoch : 58, ELBO : -694.258964 (0s), Perplexity : 1168.975830
# Epoch : 59, ELBO : -694.987246 (0s), Perplexity : 1166.790039
# Epoch : 60, ELBO : -694.832323 (0s), Perplexity : 1163.382812
# Epoch : 61, ELBO : -693.294001 (0s), Perplexity : 1160.015381
# Epoch : 62, ELBO : -690.733582 (0s), Perplexity : 1157.704468
# Epoch : 63, ELBO : -692.641344 (0s), Perplexity : 1155.563477
# Epoch : 64, ELBO : -692.028329 (0s), Perplexity : 1152.694092
# Epoch : 65, ELBO : -687.694916 (0s), Perplexity : 1150.361572
# Epoch : 66, ELBO : -687.165092 (0s), Perplexity : 1146.073364
# Epoch : 67, ELBO : -689.052951 (0s), Perplexity : 1141.513794
# Epoch : 68, ELBO : -689.017198 (0s), Perplexity : 1139.825562
# Epoch : 69, ELBO : -688.646282 (0s), Perplexity : 1138.563110
# Epoch : 70, ELBO : -686.413716 (0s), Perplexity : 1136.046265
# Epoch : 71, ELBO : -689.396831 (0s), Perplexity : 1134.022095
# Epoch : 72, ELBO : -685.576299 (0s), Perplexity : 1131.675537
# Epoch : 73, ELBO : -687.511608 (0s), Perplexity : 1127.669434
# Epoch : 74, ELBO : -683.996740 (0s), Perplexity : 1125.169189
# Epoch : 75, ELBO : -687.243916 (0s), Perplexity : 1123.250000
# Epoch : 76, ELBO : -690.246493 (0s), Perplexity : 1123.251587
# Epoch : 77, ELBO : -687.102714 (0s), Perplexity : 1120.295776
# Epoch : 78, ELBO : -686.499809 (0s), Perplexity : 1118.269287
# Epoch : 79, ELBO : -687.485035 (0s), Perplexity : 1115.303589
# Epoch : 80, ELBO : -686.866544 (0s), Perplexity : 1115.347778
# Epoch : 81, ELBO : -686.711920 (0s), Perplexity : 1110.367065
# Epoch : 82, ELBO : -686.037109 (0s), Perplexity : 1108.557739
# Epoch : 83, ELBO : -682.597221 (0s), Perplexity : 1106.055542
# Epoch : 84, ELBO : -685.827734 (0s), Perplexity : 1104.772583
# Epoch : 85, ELBO : -685.484550 (0s), Perplexity : 1103.875244
# Epoch : 86, ELBO : -675.990692 (0s), Perplexity : 1102.063477
# Epoch : 87, ELBO : -680.216719 (0s), Perplexity : 1098.250122
# Epoch : 88, ELBO : -682.785706 (0s), Perplexity : 1094.766846
# Epoch : 89, ELBO : -683.265952 (0s), Perplexity : 1094.552368
# Epoch : 90, ELBO : -683.496724 (0s), Perplexity : 1091.086548
# Epoch : 91, ELBO : -680.336717 (0s), Perplexity : 1091.876587
# Epoch : 92, ELBO : -683.805689 (0s), Perplexity : 1087.544067
# Epoch : 93, ELBO : -683.159033 (0s), Perplexity : 1087.285278
# Epoch : 94, ELBO : -683.601263 (0s), Perplexity : 1084.124756
# Epoch : 95, ELBO : -682.483107 (0s), Perplexity : 1081.903076
# Epoch : 96, ELBO : -681.211212 (0s), Perplexity : 1081.645752
# Epoch : 97, ELBO : -678.133992 (0s), Perplexity : 1079.470337
# Epoch : 98, ELBO : -679.341101 (0s), Perplexity : 1077.748901
# Epoch : 99, ELBO : -677.967207 (0s), Perplexity : 1076.024048
# Epoch : 100, ELBO : -681.188230 (0s), Perplexity : 1073.324463
# Epoch : 101, ELBO : -678.923509 (0s), Perplexity : 1073.836426
# Epoch : 102, ELBO : -680.634752 (0s), Perplexity : 1073.790283
# Epoch : 103, ELBO : -678.540061 (0s), Perplexity : 1068.975342
# Epoch : 104, ELBO : -683.171237 (0s), Perplexity : 1070.388184
# Epoch : 105, ELBO : -679.430742 (0s), Perplexity : 1067.543457
# Epoch : 106, ELBO : -681.784268 (0s), Perplexity : 1066.237061
# Epoch : 107, ELBO : -676.214666 (0s), Perplexity : 1065.822266
# Epoch : 108, ELBO : -680.979054 (0s), Perplexity : 1062.144531
# Epoch : 109, ELBO : -677.584589 (0s), Perplexity : 1059.478760
# Epoch : 110, ELBO : -676.355394 (0s), Perplexity : 1060.620117
# Epoch : 111, ELBO : -676.808827 (0s), Perplexity : 1058.090820
# Epoch : 112, ELBO : -677.879780 (0s), Perplexity : 1057.945068
# Epoch : 113, ELBO : -677.718520 (0s), Perplexity : 1055.802246
# Epoch : 114, ELBO : -673.674982 (0s), Perplexity : 1054.222534
# Epoch : 115, ELBO : -680.062672 (0s), Perplexity : 1053.079102
# Epoch : 116, ELBO : -674.857219 (0s), Perplexity : 1052.227295
# Epoch : 117, ELBO : -674.546928 (0s), Perplexity : 1049.351196
# Epoch : 118, ELBO : -676.752403 (0s), Perplexity : 1049.007568
# Epoch : 119, ELBO : -674.762068 (0s), Perplexity : 1047.604858
# Epoch : 120, ELBO : -676.753543 (0s), Perplexity : 1046.889282
# Epoch : 121, ELBO : -677.172078 (0s), Perplexity : 1046.616821
# Epoch : 122, ELBO : -671.406067 (0s), Perplexity : 1043.063477
# Epoch : 123, ELBO : -670.086897 (0s), Perplexity : 1043.367432
# Epoch : 124, ELBO : -674.650155 (0s), Perplexity : 1040.453125
# Epoch : 125, ELBO : -675.097956 (0s), Perplexity : 1039.406738
# Epoch : 126, ELBO : -674.281630 (0s), Perplexity : 1038.171875
# Epoch : 127, ELBO : -674.561510 (0s), Perplexity : 1038.742310
# Epoch : 128, ELBO : -674.348167 (0s), Perplexity : 1036.586060
# Epoch : 129, ELBO : -676.387107 (0s), Perplexity : 1035.800903
# Epoch : 130, ELBO : -670.098219 (0s), Perplexity : 1033.785767
# Epoch : 131, ELBO : -673.842962 (0s), Perplexity : 1032.378296
# Epoch : 132, ELBO : -672.263308 (0s), Perplexity : 1031.212280
# Epoch : 133, ELBO : -675.601970 (0s), Perplexity : 1030.721191
# Epoch : 134, ELBO : -674.527854 (0s), Perplexity : 1029.824585
# Epoch : 135, ELBO : -673.971755 (0s), Perplexity : 1026.882935
# Epoch : 136, ELBO : -671.495322 (0s), Perplexity : 1026.622070
# Epoch : 137, ELBO : -673.276037 (0s), Perplexity : 1025.784302
# Epoch : 138, ELBO : -668.625327 (0s), Perplexity : 1024.693604
# Epoch : 139, ELBO : -674.414809 (0s), Perplexity : 1024.629150
# Epoch : 140, ELBO : -674.281228 (0s), Perplexity : 1020.719177
# Epoch : 141, ELBO : -671.730444 (0s), Perplexity : 1022.135010
# Epoch : 142, ELBO : -671.774958 (0s), Perplexity : 1021.280518
# Epoch : 143, ELBO : -672.727292 (0s), Perplexity : 1018.609497
# Epoch : 144, ELBO : -672.696153 (0s), Perplexity : 1018.506042
# Epoch : 145, ELBO : -665.537703 (0s), Perplexity : 1018.467651
# Epoch : 146, ELBO : -670.827739 (0s), Perplexity : 1015.789917
# Epoch : 147, ELBO : -671.769024 (0s), Perplexity : 1016.104370
# Epoch : 148, ELBO : -672.705988 (0s), Perplexity : 1014.223267
# Epoch : 149, ELBO : -671.865337 (0s), Perplexity : 1013.902649
# Epoch : 150, ELBO : -672.007063 (0s), Perplexity : 1012.235107
# Epoch : 151, ELBO : -673.572094 (0s), Perplexity : 1012.373169
# Epoch : 152, ELBO : -673.307043 (0s), Perplexity : 1010.271606
# Epoch : 153, ELBO : -673.197734 (0s), Perplexity : 1009.092529
# Epoch : 154, ELBO : -669.501393 (0s), Perplexity : 1009.107422
# Epoch : 155, ELBO : -671.010554 (0s), Perplexity : 1006.302185
# Epoch : 156, ELBO : -672.526159 (0s), Perplexity : 1006.429871
# Epoch : 157, ELBO : -668.746138 (0s), Perplexity : 1003.728271
# Epoch : 158, ELBO : -669.398202 (0s), Perplexity : 1002.820740
# Epoch : 159, ELBO : -672.174144 (0s), Perplexity : 1000.844482
# Epoch : 160, ELBO : -669.890384 (0s), Perplexity : 1002.417236
# Epoch : 161, ELBO : -665.383648 (0s), Perplexity : 1001.289368
# Epoch : 162, ELBO : -669.406353 (0s), Perplexity : 999.134033
# Epoch : 163, ELBO : -671.982855 (0s), Perplexity : 996.505737
# Epoch : 164, ELBO : -668.715956 (0s), Perplexity : 996.799927
# Epoch : 165, ELBO : -669.502353 (0s), Perplexity : 996.766174
# Epoch : 166, ELBO : -671.041160 (0s), Perplexity : 995.456665
# Epoch : 167, ELBO : -669.127494 (0s), Perplexity : 992.554932
# Epoch : 168, ELBO : -671.884180 (0s), Perplexity : 991.744080
# Epoch : 169, ELBO : -669.231906 (0s), Perplexity : 991.638123
# Epoch : 170, ELBO : -667.058033 (0s), Perplexity : 990.701904
# Epoch : 171, ELBO : -669.296739 (0s), Perplexity : 990.142212
# Epoch : 172, ELBO : -665.521188 (0s), Perplexity : 990.895569
# Epoch : 173, ELBO : -668.396332 (0s), Perplexity : 987.998230
# Epoch : 174, ELBO : -669.801333 (0s), Perplexity : 988.471313
# Epoch : 175, ELBO : -670.218026 (0s), Perplexity : 986.053528
# Epoch : 176, ELBO : -667.184637 (0s), Perplexity : 983.136108
# Epoch : 177, ELBO : -666.928894 (0s), Perplexity : 982.817383
# Epoch : 178, ELBO : -668.318848 (0s), Perplexity : 981.549072
# Epoch : 179, ELBO : -666.024456 (0s), Perplexity : 981.862244
# Epoch : 180, ELBO : -666.248829 (0s), Perplexity : 982.498230
# Epoch : 181, ELBO : -667.993955 (0s), Perplexity : 982.063599
# Epoch : 182, ELBO : -669.994898 (0s), Perplexity : 979.818848
# Epoch : 183, ELBO : -667.165408 (0s), Perplexity : 978.822327
# Epoch : 184, ELBO : -667.347362 (0s), Perplexity : 979.212158
# Epoch : 185, ELBO : -664.916365 (0s), Perplexity : 977.409119
# Epoch : 186, ELBO : -670.399470 (0s), Perplexity : 976.099915
# Epoch : 187, ELBO : -669.795776 (0s), Perplexity : 973.270874
# Epoch : 188, ELBO : -666.762998 (0s), Perplexity : 974.351868
# Epoch : 189, ELBO : -667.664032 (0s), Perplexity : 973.512695
# Epoch : 190, ELBO : -668.250424 (0s), Perplexity : 971.250488
# Epoch : 191, ELBO : -663.992212 (0s), Perplexity : 970.429688
# Epoch : 192, ELBO : -666.407457 (0s), Perplexity : 968.802673
# Epoch : 193, ELBO : -666.836148 (0s), Perplexity : 970.074829
# Epoch : 194, ELBO : -667.490107 (0s), Perplexity : 968.476624
# Epoch : 195, ELBO : -666.865037 (0s), Perplexity : 965.497925
# Epoch : 196, ELBO : -666.964633 (0s), Perplexity : 966.846863
# Epoch : 197, ELBO : -666.881026 (0s), Perplexity : 965.524597
# Epoch : 198, ELBO : -665.895147 (0s), Perplexity : 964.839783
# Epoch : 199, ELBO : -666.941551 (0s), Perplexity : 963.844238
# Epoch : 200, ELBO : -665.988029 (0s), Perplexity : 962.499939
# Epoch : 201, ELBO : -663.235307 (0s), Perplexity : 961.804443
# Epoch : 202, ELBO : -665.603380 (0s), Perplexity : 961.861755
# Epoch : 203, ELBO : -663.928780 (0s), Perplexity : 960.827148
# Epoch : 204, ELBO : -665.390151 (0s), Perplexity : 962.169556
# Epoch : 205, ELBO : -660.330175 (0s), Perplexity : 958.704529
# Epoch : 206, ELBO : -666.371146 (0s), Perplexity : 957.455078
# Epoch : 207, ELBO : -667.655656 (0s), Perplexity : 955.593689
# Epoch : 208, ELBO : -667.494351 (0s), Perplexity : 954.901794
# Epoch : 209, ELBO : -660.908134 (0s), Perplexity : 956.144287
# Epoch : 210, ELBO : -659.882380 (0s), Perplexity : 954.868530
# Epoch : 211, ELBO : -665.531059 (0s), Perplexity : 954.329590
# Epoch : 212, ELBO : -664.250502 (0s), Perplexity : 953.774170
# Epoch : 213, ELBO : -664.884585 (0s), Perplexity : 951.052429
# Epoch : 214, ELBO : -659.041496 (0s), Perplexity : 950.667053
# Epoch : 215, ELBO : -663.210391 (0s), Perplexity : 948.862793
# Epoch : 216, ELBO : -666.605483 (0s), Perplexity : 949.398621
# Epoch : 217, ELBO : -662.531619 (0s), Perplexity : 947.422791
# Epoch : 218, ELBO : -665.953666 (0s), Perplexity : 945.756775
# Epoch : 219, ELBO : -664.391277 (0s), Perplexity : 944.185120
# Epoch : 220, ELBO : -665.138411 (0s), Perplexity : 946.115845
# Epoch : 221, ELBO : -662.632405 (0s), Perplexity : 945.222534
# Epoch : 222, ELBO : -660.826818 (0s), Perplexity : 942.326172
# Epoch : 223, ELBO : -663.393935 (0s), Perplexity : 942.928040
# Epoch : 224, ELBO : -661.447024 (0s), Perplexity : 941.709473
# Epoch : 225, ELBO : -664.954989 (0s), Perplexity : 941.394287
# Epoch : 226, ELBO : -664.927396 (0s), Perplexity : 941.139771
# Epoch : 227, ELBO : -662.564928 (0s), Perplexity : 938.954590
# Epoch : 228, ELBO : -659.652793 (0s), Perplexity : 938.340454
# Epoch : 229, ELBO : -666.311174 (0s), Perplexity : 938.498901
# Epoch : 230, ELBO : -661.028165 (0s), Perplexity : 938.078308
# Epoch : 231, ELBO : -664.637981 (0s), Perplexity : 935.674866
# Epoch : 232, ELBO : -662.916435 (0s), Perplexity : 934.595764
# Epoch : 233, ELBO : -661.241497 (0s), Perplexity : 934.781189
# Epoch : 234, ELBO : -662.765464 (0s), Perplexity : 933.652344
# Epoch : 235, ELBO : -662.020330 (0s), Perplexity : 931.759949
# Epoch : 236, ELBO : -658.505812 (0s), Perplexity : 931.671082
# Epoch : 237, ELBO : -662.132643 (0s), Perplexity : 932.084351
# Epoch : 238, ELBO : -656.658983 (0s), Perplexity : 931.405945
# Epoch : 239, ELBO : -663.071575 (0s), Perplexity : 928.511597
# Epoch : 240, ELBO : -660.778451 (0s), Perplexity : 929.372681
# Epoch : 241, ELBO : -662.127222 (0s), Perplexity : 930.205322
# Epoch : 242, ELBO : -660.530717 (0s), Perplexity : 927.903015
# Epoch : 243, ELBO : -662.207528 (0s), Perplexity : 926.322998
# Epoch : 244, ELBO : -659.264216 (0s), Perplexity : 925.847412
# Epoch : 245, ELBO : -660.458835 (0s), Perplexity : 924.194275
# Epoch : 246, ELBO : -658.478721 (0s), Perplexity : 924.268738
# Epoch : 247, ELBO : -662.499870 (0s), Perplexity : 923.324280
# Epoch : 248, ELBO : -662.598128 (0s), Perplexity : 922.101990
# Epoch : 249, ELBO : -661.590870 (0s), Perplexity : 922.616577
# Epoch : 250, ELBO : -662.484128 (0s), Perplexity : 921.454590
# Epoch : 251, ELBO : -659.226979 (0s), Perplexity : 921.326294
# Epoch : 252, ELBO : -661.930195 (0s), Perplexity : 920.087769
# Epoch : 253, ELBO : -660.425176 (0s), Perplexity : 920.924805
# Epoch : 254, ELBO : -660.233152 (0s), Perplexity : 918.974548
# Epoch : 255, ELBO : -658.492365 (0s), Perplexity : 916.485413
# Epoch : 256, ELBO : -662.464405 (0s), Perplexity : 918.985046
# Epoch : 257, ELBO : -658.986608 (0s), Perplexity : 917.116211
# Epoch : 258, ELBO : -660.050287 (0s), Perplexity : 915.321045
# Epoch : 259, ELBO : -659.765115 (0s), Perplexity : 917.115356
# Epoch : 260, ELBO : -657.529655 (0s), Perplexity : 915.168762
# Epoch : 261, ELBO : -658.946433 (0s), Perplexity : 915.342468
# Epoch : 262, ELBO : -660.628274 (0s), Perplexity : 912.399719
# Epoch : 263, ELBO : -659.880585 (0s), Perplexity : 912.555481
# Epoch : 264, ELBO : -657.680137 (0s), Perplexity : 911.692139
# Epoch : 265, ELBO : -659.197363 (0s), Perplexity : 910.820496
# Epoch : 266, ELBO : -660.754639 (0s), Perplexity : 910.224792
# Epoch : 267, ELBO : -659.474776 (0s), Perplexity : 908.460449
# Epoch : 268, ELBO : -658.080408 (0s), Perplexity : 909.017273
# Epoch : 269, ELBO : -658.042392 (0s), Perplexity : 907.929932
# Epoch : 270, ELBO : -660.851895 (0s), Perplexity : 907.387207
# Epoch : 271, ELBO : -657.922635 (0s), Perplexity : 906.819275
# Epoch : 272, ELBO : -659.613414 (0s), Perplexity : 905.703491
# Epoch : 273, ELBO : -656.953078 (0s), Perplexity : 904.706421
# Epoch : 274, ELBO : -654.440488 (0s), Perplexity : 905.556274
# Epoch : 275, ELBO : -658.795571 (0s), Perplexity : 904.417908
# Epoch : 276, ELBO : -658.413336 (0s), Perplexity : 904.170349
# Epoch : 277, ELBO : -657.614277 (0s), Perplexity : 902.489197
# Epoch : 278, ELBO : -657.097909 (0s), Perplexity : 902.597656
# Epoch : 279, ELBO : -656.876631 (0s), Perplexity : 900.393311
# Epoch : 280, ELBO : -658.248460 (0s), Perplexity : 900.728210
# Epoch : 281, ELBO : -655.033603 (0s), Perplexity : 900.349060
# Epoch : 282, ELBO : -657.753579 (0s), Perplexity : 898.444031
# Epoch : 283, ELBO : -657.529641 (0s), Perplexity : 900.255493
# Epoch : 284, ELBO : -658.962794 (0s), Perplexity : 898.602966
# Epoch : 285, ELBO : -657.013600 (0s), Perplexity : 897.443420
# Epoch : 286, ELBO : -658.167425 (0s), Perplexity : 896.138733
# Epoch : 287, ELBO : -656.950384 (0s), Perplexity : 896.660645
# Epoch : 288, ELBO : -656.928683 (0s), Perplexity : 896.107971
# Epoch : 289, ELBO : -652.701854 (0s), Perplexity : 896.296387
# Epoch : 290, ELBO : -652.048942 (0s), Perplexity : 894.513855
# Epoch : 291, ELBO : -656.594419 (0s), Perplexity : 892.194336
# Epoch : 292, ELBO : -658.145014 (0s), Perplexity : 892.535645
# Epoch : 293, ELBO : -653.911718 (0s), Perplexity : 891.938721
# Epoch : 294, ELBO : -656.577032 (0s), Perplexity : 891.582397
# Epoch : 295, ELBO : -651.934507 (0s), Perplexity : 891.672058
# Epoch : 296, ELBO : -657.171922 (0s), Perplexity : 889.502502
# Epoch : 297, ELBO : -652.390927 (0s), Perplexity : 889.577148
# Epoch : 298, ELBO : -657.813748 (0s), Perplexity : 889.436707
# Epoch : 299, ELBO : -657.441906 (0s), Perplexity : 886.937134
# Epoch : 300, ELBO : -657.217912 (0s), Perplexity : 886.782776
# Epoch : 301, ELBO : -657.665563 (0s), Perplexity : 886.018555
# Epoch : 302, ELBO : -654.828924 (0s), Perplexity : 883.979919
# Epoch : 303, ELBO : -656.205308 (0s), Perplexity : 886.589539
# Epoch : 304, ELBO : -652.447807 (0s), Perplexity : 886.062500
# Epoch : 305, ELBO : -658.376526 (0s), Perplexity : 882.014465
# Epoch : 306, ELBO : -656.072304 (0s), Perplexity : 882.835815
# Epoch : 307, ELBO : -657.969122 (0s), Perplexity : 882.782776
# Epoch : 308, ELBO : -658.704645 (0s), Perplexity : 880.820801
# Epoch : 309, ELBO : -653.775948 (0s), Perplexity : 880.766235
# Epoch : 310, ELBO : -657.826266 (0s), Perplexity : 881.106873
# Epoch : 311, ELBO : -655.264446 (0s), Perplexity : 880.397949
# Epoch : 312, ELBO : -656.618874 (0s), Perplexity : 879.903992
# Epoch : 313, ELBO : -654.574732 (0s), Perplexity : 879.354980
# Epoch : 314, ELBO : -657.026886 (0s), Perplexity : 876.553406
# Epoch : 315, ELBO : -652.599171 (0s), Perplexity : 879.027954
# Epoch : 316, ELBO : -657.734558 (0s), Perplexity : 877.544983
# Epoch : 317, ELBO : -655.211212 (0s), Perplexity : 875.317932
# Epoch : 318, ELBO : -654.496834 (0s), Perplexity : 874.538574
# Epoch : 319, ELBO : -651.156375 (0s), Perplexity : 875.916626
# Epoch : 320, ELBO : -653.979914 (0s), Perplexity : 873.592041
# Epoch : 321, ELBO : -657.001437 (0s), Perplexity : 875.892029
# Epoch : 322, ELBO : -656.082789 (0s), Perplexity : 872.920410
# Epoch : 323, ELBO : -654.793127 (0s), Perplexity : 872.170654
# Epoch : 324, ELBO : -654.187508 (0s), Perplexity : 871.365051
# Epoch : 325, ELBO : -652.826177 (0s), Perplexity : 872.933289
# Epoch : 326, ELBO : -651.249603 (0s), Perplexity : 872.127808
# Epoch : 327, ELBO : -654.985171 (0s), Perplexity : 869.624634
# Epoch : 328, ELBO : -657.176741 (0s), Perplexity : 867.771362
# Epoch : 329, ELBO : -654.999035 (0s), Perplexity : 868.614258
# Epoch : 330, ELBO : -651.818193 (0s), Perplexity : 867.869019
# Epoch : 331, ELBO : -651.294725 (0s), Perplexity : 867.257996
# Epoch : 332, ELBO : -652.734311 (0s), Perplexity : 866.812317
# Epoch : 333, ELBO : -655.490567 (0s), Perplexity : 867.279114
# Epoch : 334, ELBO : -652.642703 (0s), Perplexity : 866.535828
# Epoch : 335, ELBO : -654.451607 (0s), Perplexity : 865.576111
# Epoch : 336, ELBO : -653.309154 (0s), Perplexity : 864.408875
# Epoch : 337, ELBO : -653.433128 (0s), Perplexity : 864.120361
# Epoch : 338, ELBO : -651.380463 (0s), Perplexity : 864.139343
# Epoch : 339, ELBO : -652.437062 (0s), Perplexity : 862.769897
# Epoch : 340, ELBO : -653.987565 (0s), Perplexity : 863.645386
# Epoch : 341, ELBO : -654.579348 (0s), Perplexity : 861.565796
# Epoch : 342, ELBO : -654.964164 (0s), Perplexity : 861.063477
# Epoch : 343, ELBO : -653.431946 (0s), Perplexity : 863.224243
# Epoch : 344, ELBO : -652.314855 (0s), Perplexity : 859.974854
# Epoch : 345, ELBO : -648.046145 (0s), Perplexity : 859.722290
# Epoch : 346, ELBO : -650.386544 (0s), Perplexity : 858.822510
# Epoch : 347, ELBO : -648.199749 (0s), Perplexity : 857.593201
# Epoch : 348, ELBO : -652.219369 (0s), Perplexity : 859.043274
# Epoch : 349, ELBO : -647.310797 (0s), Perplexity : 858.049316
# Epoch : 350, ELBO : -654.055403 (0s), Perplexity : 856.190918
# Epoch : 351, ELBO : -653.322207 (0s), Perplexity : 856.360779
# Epoch : 352, ELBO : -653.045804 (0s), Perplexity : 855.440857
# Epoch : 353, ELBO : -651.642309 (0s), Perplexity : 857.263672
# Epoch : 354, ELBO : -653.114324 (0s), Perplexity : 853.765198
# Epoch : 355, ELBO : -651.943132 (0s), Perplexity : 855.271606
# Epoch : 356, ELBO : -651.852847 (0s), Perplexity : 851.580627
# Epoch : 357, ELBO : -649.771201 (0s), Perplexity : 852.089966
# Epoch : 358, ELBO : -654.985629 (0s), Perplexity : 853.064453
# Epoch : 359, ELBO : -650.446428 (0s), Perplexity : 851.818604
# Epoch : 360, ELBO : -650.797896 (0s), Perplexity : 851.698792
# Epoch : 361, ELBO : -650.653376 (0s), Perplexity : 850.466675
# Epoch : 362, ELBO : -651.984086 (0s), Perplexity : 850.581055
# Epoch : 363, ELBO : -653.078605 (0s), Perplexity : 850.145569
# Epoch : 364, ELBO : -653.131356 (0s), Perplexity : 848.529602
# Epoch : 365, ELBO : -652.267595 (0s), Perplexity : 849.341675
# Epoch : 366, ELBO : -650.938624 (0s), Perplexity : 848.575745
# Epoch : 367, ELBO : -654.742493 (0s), Perplexity : 847.974670
# Epoch : 368, ELBO : -650.873582 (0s), Perplexity : 847.207153
# Epoch : 369, ELBO : -651.543460 (0s), Perplexity : 844.943909
# Epoch : 370, ELBO : -651.885312 (0s), Perplexity : 844.361084
# Epoch : 371, ELBO : -650.638178 (0s), Perplexity : 844.493530
# Epoch : 372, ELBO : -649.073783 (0s), Perplexity : 844.606323
# Epoch : 373, ELBO : -643.312428 (0s), Perplexity : 844.753723
# Epoch : 374, ELBO : -648.769897 (0s), Perplexity : 845.161865
# Epoch : 375, ELBO : -653.449751 (0s), Perplexity : 843.276733
# Epoch : 376, ELBO : -649.603568 (0s), Perplexity : 844.192017
# Epoch : 377, ELBO : -653.733171 (0s), Perplexity : 841.284607
# Epoch : 378, ELBO : -651.632285 (0s), Perplexity : 841.987366
# Epoch : 379, ELBO : -652.939564 (0s), Perplexity : 840.740051
# Epoch : 380, ELBO : -649.937256 (0s), Perplexity : 840.893982
# Epoch : 381, ELBO : -651.521884 (0s), Perplexity : 839.551025
# Epoch : 382, ELBO : -650.807143 (0s), Perplexity : 839.530579
# Epoch : 383, ELBO : -651.646121 (0s), Perplexity : 838.438416
# Epoch : 384, ELBO : -650.333066 (0s), Perplexity : 837.985168
# Epoch : 385, ELBO : -650.534834 (0s), Perplexity : 837.440735
# Epoch : 386, ELBO : -646.046256 (0s), Perplexity : 838.067932
# Epoch : 387, ELBO : -648.191531 (0s), Perplexity : 835.927490
# Epoch : 388, ELBO : -649.800107 (0s), Perplexity : 835.497498
# Epoch : 389, ELBO : -648.346527 (0s), Perplexity : 836.711487
# Epoch : 390, ELBO : -649.726790 (0s), Perplexity : 836.127563
# Epoch : 391, ELBO : -648.986675 (0s), Perplexity : 835.063354
# Epoch : 392, ELBO : -650.885967 (0s), Perplexity : 835.381958
# Epoch : 393, ELBO : -650.759250 (0s), Perplexity : 834.262573
# Epoch : 394, ELBO : -647.343903 (0s), Perplexity : 834.900513
# Epoch : 395, ELBO : -651.539165 (0s), Perplexity : 832.009277
# Epoch : 396, ELBO : -645.597764 (0s), Perplexity : 832.356873
# Epoch : 397, ELBO : -650.492584 (0s), Perplexity : 830.792969
# Epoch : 398, ELBO : -649.729623 (0s), Perplexity : 831.619385
# Epoch : 399, ELBO : -649.856484 (0s), Perplexity : 828.216064
# Epoch : 400, ELBO : -649.075994 (0s), Perplexity : 828.466064
# Epoch : 401, ELBO : -647.784388 (0s), Perplexity : 830.171265
# Epoch : 402, ELBO : -649.598899 (0s), Perplexity : 829.447571
# Epoch : 403, ELBO : -648.721605 (0s), Perplexity : 830.329224
# Epoch : 404, ELBO : -649.670885 (0s), Perplexity : 829.028809
# Epoch : 405, ELBO : -650.112310 (0s), Perplexity : 826.995056
# Epoch : 406, ELBO : -648.255316 (0s), Perplexity : 827.094849
# Epoch : 407, ELBO : -647.948839 (0s), Perplexity : 827.452209
# Epoch : 408, ELBO : -650.520647 (0s), Perplexity : 825.618347
# Epoch : 409, ELBO : -649.976463 (0s), Perplexity : 826.032654
# Epoch : 410, ELBO : -648.943995 (0s), Perplexity : 824.840027
# Epoch : 411, ELBO : -649.024708 (0s), Perplexity : 825.311768
# Epoch : 412, ELBO : -649.555223 (0s), Perplexity : 825.388123
# Epoch : 413, ELBO : -649.682818 (0s), Perplexity : 825.069763
# Epoch : 414, ELBO : -648.479928 (0s), Perplexity : 822.000854
# Epoch : 415, ELBO : -651.118491 (0s), Perplexity : 820.327332
# Epoch : 416, ELBO : -645.717066 (0s), Perplexity : 821.806885
# Epoch : 417, ELBO : -648.415968 (0s), Perplexity : 822.550171
# Epoch : 418, ELBO : -648.122586 (0s), Perplexity : 821.035645
# Epoch : 419, ELBO : -644.647752 (0s), Perplexity : 822.020447
# Epoch : 420, ELBO : -647.187869 (0s), Perplexity : 820.573425
# Epoch : 421, ELBO : -648.307831 (0s), Perplexity : 820.361755
# Epoch : 422, ELBO : -650.051905 (0s), Perplexity : 819.406250
# Epoch : 423, ELBO : -648.950922 (0s), Perplexity : 818.151428
# Epoch : 424, ELBO : -642.566711 (0s), Perplexity : 819.731812
# Epoch : 425, ELBO : -648.925082 (0s), Perplexity : 815.544922
# Epoch : 426, ELBO : -645.024189 (0s), Perplexity : 818.616211
# Epoch : 427, ELBO : -647.559845 (0s), Perplexity : 817.321289
# Epoch : 428, ELBO : -650.514707 (0s), Perplexity : 816.030334
# Epoch : 429, ELBO : -650.125031 (0s), Perplexity : 816.244385
# Epoch : 430, ELBO : -645.352253 (0s), Perplexity : 816.835083
# Epoch : 431, ELBO : -646.623205 (0s), Perplexity : 815.626953
# Epoch : 432, ELBO : -648.649680 (0s), Perplexity : 814.908936
# Epoch : 433, ELBO : -649.530362 (0s), Perplexity : 813.912415
# Epoch : 434, ELBO : -645.643987 (0s), Perplexity : 813.363464
# Epoch : 435, ELBO : -647.429898 (0s), Perplexity : 813.219604
# Epoch : 436, ELBO : -649.586648 (0s), Perplexity : 811.896790
# Epoch : 437, ELBO : -642.732239 (0s), Perplexity : 810.417358
# Epoch : 438, ELBO : -649.529441 (0s), Perplexity : 811.591431
# Epoch : 439, ELBO : -646.580145 (0s), Perplexity : 811.414551
# Epoch : 440, ELBO : -647.892254 (0s), Perplexity : 810.381409
# Epoch : 441, ELBO : -646.863417 (0s), Perplexity : 810.803894
# Epoch : 442, ELBO : -642.475922 (0s), Perplexity : 810.216003
# Epoch : 443, ELBO : -646.054135 (0s), Perplexity : 810.489624
# Epoch : 444, ELBO : -646.603812 (0s), Perplexity : 809.184387
# Epoch : 445, ELBO : -643.563293 (0s), Perplexity : 809.490051
# Epoch : 446, ELBO : -647.997914 (0s), Perplexity : 808.053101
# Epoch : 447, ELBO : -648.734483 (0s), Perplexity : 809.502747
# Epoch : 448, ELBO : -645.540316 (0s), Perplexity : 808.098145
# Epoch : 449, ELBO : -644.079301 (0s), Perplexity : 807.548889
# Epoch : 450, ELBO : -645.321026 (0s), Perplexity : 806.655640
# Epoch : 451, ELBO : -644.877577 (0s), Perplexity : 806.856079
# Epoch : 452, ELBO : -648.546082 (0s), Perplexity : 804.578125
# Epoch : 453, ELBO : -641.218642 (0s), Perplexity : 805.714172
# Epoch : 454, ELBO : -648.717293 (0s), Perplexity : 805.762207
# Epoch : 455, ELBO : -646.784626 (0s), Perplexity : 804.777649
# Epoch : 456, ELBO : -640.207686 (0s), Perplexity : 804.599243
# Epoch : 457, ELBO : -643.264332 (0s), Perplexity : 801.640137
# Epoch : 458, ELBO : -644.678944 (0s), Perplexity : 802.700806
# Epoch : 459, ELBO : -648.027779 (0s), Perplexity : 801.758301
# Epoch : 460, ELBO : -647.549136 (0s), Perplexity : 801.608032
# Epoch : 461, ELBO : -645.889157 (0s), Perplexity : 800.390015
# Epoch : 462, ELBO : -643.999662 (0s), Perplexity : 800.243469
# Epoch : 463, ELBO : -647.250344 (0s), Perplexity : 801.793091
# Epoch : 464, ELBO : -645.550864 (0s), Perplexity : 799.439514
# Epoch : 465, ELBO : -644.918318 (0s), Perplexity : 798.945251
# Epoch : 466, ELBO : -645.945143 (0s), Perplexity : 800.161804
# Epoch : 467, ELBO : -645.414190 (0s), Perplexity : 799.118958
# Epoch : 468, ELBO : -642.977131 (0s), Perplexity : 799.010010
# Epoch : 469, ELBO : -646.343911 (0s), Perplexity : 797.396545
# Epoch : 470, ELBO : -648.251171 (0s), Perplexity : 797.410645
# Epoch : 471, ELBO : -644.777585 (0s), Perplexity : 797.149109
# Epoch : 472, ELBO : -646.280493 (0s), Perplexity : 797.868958
# Epoch : 473, ELBO : -645.029155 (0s), Perplexity : 796.408997
# Epoch : 474, ELBO : -646.987341 (0s), Perplexity : 796.908142
# Epoch : 475, ELBO : -646.601926 (0s), Perplexity : 795.689636
# Epoch : 476, ELBO : -646.380571 (0s), Perplexity : 793.947021
# Epoch : 477, ELBO : -646.868344 (0s), Perplexity : 792.695251
# Epoch : 478, ELBO : -640.499087 (0s), Perplexity : 794.145020
# Epoch : 479, ELBO : -645.312808 (0s), Perplexity : 794.099243
# Epoch : 480, ELBO : -644.536136 (0s), Perplexity : 795.315613
# Epoch : 481, ELBO : -643.935472 (0s), Perplexity : 792.414124
# Epoch : 482, ELBO : -642.431960 (0s), Perplexity : 793.601074
# Epoch : 483, ELBO : -645.541618 (0s), Perplexity : 793.062744
# Epoch : 484, ELBO : -645.073614 (0s), Perplexity : 790.724243
# Epoch : 485, ELBO : -638.425640 (0s), Perplexity : 792.096802
# Epoch : 486, ELBO : -640.933605 (0s), Perplexity : 792.906250
# Epoch : 487, ELBO : -643.703733 (0s), Perplexity : 791.467041
# Epoch : 488, ELBO : -642.519362 (0s), Perplexity : 789.396301
# Epoch : 489, ELBO : -646.518971 (0s), Perplexity : 789.284119
# Epoch : 490, ELBO : -641.250444 (0s), Perplexity : 789.000427
# Epoch : 491, ELBO : -644.299610 (0s), Perplexity : 788.066406
# Epoch : 492, ELBO : -643.813932 (0s), Perplexity : 788.728088
# Epoch : 493, ELBO : -645.210863 (0s), Perplexity : 788.041260
# Epoch : 494, ELBO : -641.655809 (0s), Perplexity : 788.623901
# Epoch : 495, ELBO : -638.446356 (0s), Perplexity : 786.916992
# Epoch : 496, ELBO : -641.767731 (0s), Perplexity : 787.961182
# Epoch : 497, ELBO : -640.728921 (0s), Perplexity : 787.187561
# Epoch : 498, ELBO : -640.561049 (0s), Perplexity : 786.407227
# Epoch : 499, ELBO : -641.890886 (0s), Perplexity : 786.249756
# Epoch : 500, ELBO : -643.417367 (0s), Perplexity : 785.082031
# Epoch : 501, ELBO : -636.770067 (0s), Perplexity : 784.650513
# Epoch : 502, ELBO : -643.352689 (0s), Perplexity : 784.973816
# Epoch : 503, ELBO : -643.288078 (0s), Perplexity : 784.481750
# Epoch : 504, ELBO : -642.190083 (0s), Perplexity : 784.090210
# Epoch : 505, ELBO : -640.948778 (0s), Perplexity : 784.050598
# Epoch : 506, ELBO : -644.787082 (0s), Perplexity : 782.280090
# Epoch : 507, ELBO : -639.069913 (0s), Perplexity : 782.472229
# Epoch : 508, ELBO : -641.197776 (0s), Perplexity : 783.665222
# Epoch : 509, ELBO : -644.981861 (0s), Perplexity : 781.932495
# Epoch : 510, ELBO : -644.981295 (0s), Perplexity : 779.116211
# Epoch : 511, ELBO : -644.406555 (0s), Perplexity : 780.413513
# Epoch : 512, ELBO : -642.124251 (0s), Perplexity : 780.243103
# Epoch : 513, ELBO : -640.642819 (0s), Perplexity : 778.693176
# Epoch : 514, ELBO : -643.947984 (0s), Perplexity : 779.166016
# Epoch : 515, ELBO : -640.956554 (0s), Perplexity : 778.840942
# Epoch : 516, ELBO : -642.874448 (0s), Perplexity : 778.317871
# Epoch : 517, ELBO : -642.918274 (0s), Perplexity : 778.852478
# Epoch : 518, ELBO : -641.817624 (0s), Perplexity : 778.829834
# Epoch : 519, ELBO : -645.435206 (0s), Perplexity : 776.889587
# Epoch : 520, ELBO : -638.541035 (0s), Perplexity : 777.998413
# Epoch : 521, ELBO : -643.146953 (0s), Perplexity : 775.908142
# Epoch : 522, ELBO : -639.782659 (0s), Perplexity : 774.951233
# Epoch : 523, ELBO : -643.471896 (0s), Perplexity : 775.853027
# Epoch : 524, ELBO : -641.679527 (0s), Perplexity : 775.396606
# Epoch : 525, ELBO : -644.111925 (0s), Perplexity : 775.036194
# Epoch : 526, ELBO : -640.370994 (0s), Perplexity : 775.682495
# Epoch : 527, ELBO : -640.287079 (0s), Perplexity : 774.181885
# Epoch : 528, ELBO : -641.540938 (0s), Perplexity : 774.623535
# Epoch : 529, ELBO : -640.379727 (0s), Perplexity : 775.049866
# Epoch : 530, ELBO : -641.803203 (0s), Perplexity : 774.109924
# Epoch : 531, ELBO : -640.604201 (0s), Perplexity : 775.604797
# Epoch : 532, ELBO : -641.527668 (0s), Perplexity : 773.678894
# Epoch : 533, ELBO : -639.208324 (0s), Perplexity : 771.372864
# Epoch : 534, ELBO : -637.773229 (0s), Perplexity : 772.487427
# Epoch : 535, ELBO : -641.581848 (0s), Perplexity : 769.569763
# Epoch : 536, ELBO : -643.506181 (0s), Perplexity : 769.380066
# Epoch : 537, ELBO : -638.712638 (0s), Perplexity : 772.019043
# Epoch : 538, ELBO : -642.823545 (0s), Perplexity : 769.635437
# Epoch : 539, ELBO : -643.415852 (0s), Perplexity : 769.539673
# Epoch : 540, ELBO : -642.960435 (0s), Perplexity : 768.365967
# Epoch : 541, ELBO : -639.654111 (0s), Perplexity : 769.021729
# Epoch : 542, ELBO : -641.682040 (0s), Perplexity : 767.689514
# Epoch : 543, ELBO : -644.364163 (0s), Perplexity : 767.246033
# Epoch : 544, ELBO : -642.568873 (0s), Perplexity : 766.827942
# Epoch : 545, ELBO : -642.465915 (0s), Perplexity : 767.787292
# Epoch : 546, ELBO : -639.821189 (0s), Perplexity : 767.244934
# Epoch : 547, ELBO : -638.675662 (0s), Perplexity : 768.442932
# Epoch : 548, ELBO : -640.816428 (0s), Perplexity : 766.430603
# Epoch : 549, ELBO : -644.091847 (0s), Perplexity : 765.432434
# Epoch : 550, ELBO : -640.426061 (0s), Perplexity : 766.619934
# Epoch : 551, ELBO : -637.979711 (0s), Perplexity : 766.304138
# Epoch : 552, ELBO : -643.086134 (0s), Perplexity : 763.879883
# Epoch : 553, ELBO : -642.537664 (0s), Perplexity : 765.692322
# Epoch : 554, ELBO : -641.586537 (0s), Perplexity : 763.325317
# Epoch : 555, ELBO : -641.190657 (0s), Perplexity : 763.909058
# Epoch : 556, ELBO : -639.470059 (0s), Perplexity : 762.430481
# Epoch : 557, ELBO : -639.961370 (0s), Perplexity : 762.854858
# Epoch : 558, ELBO : -636.536607 (0s), Perplexity : 763.643921
# Epoch : 559, ELBO : -641.421143 (0s), Perplexity : 763.648621
# Epoch : 560, ELBO : -638.688019 (0s), Perplexity : 763.072449
# Epoch : 561, ELBO : -640.538757 (0s), Perplexity : 760.650391
# Epoch : 562, ELBO : -639.420205 (0s), Perplexity : 760.986328
# Epoch : 563, ELBO : -643.377464 (0s), Perplexity : 760.513672
# Epoch : 564, ELBO : -640.980064 (0s), Perplexity : 759.902161
# Epoch : 565, ELBO : -641.173248 (0s), Perplexity : 761.123169
# Epoch : 566, ELBO : -640.015495 (0s), Perplexity : 761.283936
# Epoch : 567, ELBO : -639.897114 (0s), Perplexity : 758.882446
# Epoch : 568, ELBO : -639.918968 (0s), Perplexity : 759.424377
# Epoch : 569, ELBO : -639.973336 (0s), Perplexity : 758.833618
# Epoch : 570, ELBO : -640.783272 (0s), Perplexity : 758.986694
# Epoch : 571, ELBO : -638.239083 (0s), Perplexity : 758.511292
# Epoch : 572, ELBO : -641.477009 (0s), Perplexity : 757.727539
# Epoch : 573, ELBO : -638.157884 (0s), Perplexity : 756.773193
# Epoch : 574, ELBO : -638.850175 (0s), Perplexity : 756.277527
# Epoch : 575, ELBO : -641.278653 (0s), Perplexity : 755.909058
# Epoch : 576, ELBO : -639.738190 (0s), Perplexity : 757.326965
# Epoch : 577, ELBO : -640.397558 (0s), Perplexity : 756.008911
# Epoch : 578, ELBO : -637.921786 (0s), Perplexity : 756.164673
# Epoch : 579, ELBO : -639.395694 (0s), Perplexity : 754.775940
# Epoch : 580, ELBO : -637.744454 (0s), Perplexity : 755.594849
# Epoch : 581, ELBO : -640.293421 (0s), Perplexity : 753.246094
# Epoch : 582, ELBO : -641.724204 (0s), Perplexity : 753.223511
# Epoch : 583, ELBO : -641.896484 (0s), Perplexity : 752.671692
# Epoch : 584, ELBO : -639.178492 (0s), Perplexity : 753.434326
# Epoch : 585, ELBO : -640.606123 (0s), Perplexity : 752.823120
# Epoch : 586, ELBO : -635.489890 (0s), Perplexity : 753.233215
# Epoch : 587, ELBO : -636.796559 (0s), Perplexity : 753.158142
# Epoch : 588, ELBO : -638.405368 (0s), Perplexity : 752.428345
# Epoch : 589, ELBO : -640.124284 (0s), Perplexity : 752.477539
# Epoch : 590, ELBO : -637.007602 (0s), Perplexity : 751.279358
# Epoch : 591, ELBO : -637.546054 (0s), Perplexity : 751.030029
# Epoch : 592, ELBO : -638.510773 (0s), Perplexity : 749.792664
# Epoch : 593, ELBO : -640.177715 (0s), Perplexity : 751.136780
# Epoch : 594, ELBO : -638.037689 (0s), Perplexity : 751.093079
# Epoch : 595, ELBO : -636.119134 (0s), Perplexity : 751.245300
# Epoch : 596, ELBO : -636.921365 (0s), Perplexity : 748.669800
# Epoch : 597, ELBO : -639.829002 (0s), Perplexity : 748.041077
# Epoch : 598, ELBO : -638.047988 (0s), Perplexity : 748.584167
# Epoch : 599, ELBO : -639.959362 (0s), Perplexity : 749.340576
# Epoch : 600, ELBO : -639.426186 (0s), Perplexity : 747.913757
# Epoch : 601, ELBO : -638.312808 (0s), Perplexity : 747.984375
# Epoch : 602, ELBO : -637.243436 (0s), Perplexity : 747.687317
# Epoch : 603, ELBO : -635.997561 (0s), Perplexity : 748.054993
# Epoch : 604, ELBO : -634.670177 (0s), Perplexity : 746.849243
# Epoch : 605, ELBO : -634.831532 (0s), Perplexity : 746.256531
# Epoch : 606, ELBO : -639.103338 (0s), Perplexity : 745.826782
# Epoch : 607, ELBO : -637.793357 (0s), Perplexity : 745.743591
# Epoch : 608, ELBO : -641.291357 (0s), Perplexity : 745.877625
# Epoch : 609, ELBO : -640.351429 (0s), Perplexity : 743.529724
# Epoch : 610, ELBO : -639.401134 (0s), Perplexity : 745.448120
# Epoch : 611, ELBO : -636.443293 (0s), Perplexity : 743.524048
# Epoch : 612, ELBO : -636.491524 (0s), Perplexity : 743.588562
# Epoch : 613, ELBO : -636.591296 (0s), Perplexity : 744.331421
# Epoch : 614, ELBO : -632.370969 (0s), Perplexity : 744.213562
# Epoch : 615, ELBO : -634.180908 (0s), Perplexity : 742.591492
# Epoch : 616, ELBO : -641.048273 (0s), Perplexity : 742.907410
# Epoch : 617, ELBO : -636.725705 (0s), Perplexity : 742.500488
# Epoch : 618, ELBO : -636.265212 (0s), Perplexity : 741.135803
# Epoch : 619, ELBO : -639.727353 (0s), Perplexity : 740.534912
# Epoch : 620, ELBO : -638.412051 (0s), Perplexity : 741.241089
# Epoch : 621, ELBO : -638.820224 (0s), Perplexity : 740.378845
# Epoch : 622, ELBO : -637.842033 (0s), Perplexity : 741.135803
# Epoch : 623, ELBO : -634.797466 (0s), Perplexity : 741.052734
# Epoch : 624, ELBO : -637.351754 (0s), Perplexity : 739.273254
# Epoch : 625, ELBO : -638.253171 (0s), Perplexity : 739.927795
# Epoch : 626, ELBO : -637.574957 (0s), Perplexity : 740.337158
# Epoch : 627, ELBO : -638.953719 (0s), Perplexity : 738.675964
# Epoch : 628, ELBO : -639.897786 (0s), Perplexity : 737.027649
# Epoch : 629, ELBO : -636.206152 (0s), Perplexity : 739.380432
# Epoch : 630, ELBO : -637.312023 (0s), Perplexity : 737.121826
# Epoch : 631, ELBO : -635.822030 (0s), Perplexity : 737.649963
# Epoch : 632, ELBO : -639.857416 (0s), Perplexity : 738.185486
# Epoch : 633, ELBO : -638.908529 (0s), Perplexity : 736.040710
# Epoch : 634, ELBO : -639.260459 (0s), Perplexity : 738.094666
# Epoch : 635, ELBO : -630.218570 (0s), Perplexity : 737.399902
# Epoch : 636, ELBO : -635.701058 (0s), Perplexity : 737.573975
# Epoch : 637, ELBO : -636.605846 (0s), Perplexity : 735.793335
# Epoch : 638, ELBO : -638.262665 (0s), Perplexity : 735.379089
# Epoch : 639, ELBO : -638.481434 (0s), Perplexity : 734.112549
# Epoch : 640, ELBO : -637.152133 (0s), Perplexity : 734.141968
# Epoch : 641, ELBO : -633.797352 (0s), Perplexity : 733.862305
# Epoch : 642, ELBO : -634.418568 (0s), Perplexity : 735.023621
# Epoch : 643, ELBO : -637.597137 (0s), Perplexity : 734.686523
# Epoch : 644, ELBO : -638.131694 (0s), Perplexity : 734.478821
# Epoch : 645, ELBO : -637.109214 (0s), Perplexity : 734.068481
# Epoch : 646, ELBO : -636.108016 (0s), Perplexity : 733.365906
# Epoch : 647, ELBO : -637.425917 (0s), Perplexity : 732.771667
# Epoch : 648, ELBO : -635.987166 (0s), Perplexity : 732.476135
# Epoch : 649, ELBO : -637.626298 (0s), Perplexity : 731.842834
# Epoch : 650, ELBO : -627.727023 (0s), Perplexity : 732.094482
# Epoch : 651, ELBO : -636.116536 (0s), Perplexity : 731.180420
# Epoch : 652, ELBO : -636.521021 (0s), Perplexity : 731.795715
# Epoch : 653, ELBO : -634.439600 (0s), Perplexity : 730.794617
# Epoch : 654, ELBO : -633.245933 (0s), Perplexity : 730.523865
# Epoch : 655, ELBO : -635.801408 (0s), Perplexity : 730.443054
# Epoch : 656, ELBO : -635.885456 (0s), Perplexity : 731.566528
# Epoch : 657, ELBO : -633.002702 (0s), Perplexity : 730.976868
# Epoch : 658, ELBO : -637.673698 (0s), Perplexity : 728.999023
# Epoch : 659, ELBO : -638.045538 (0s), Perplexity : 728.901001
# Epoch : 660, ELBO : -636.845514 (0s), Perplexity : 729.312988
# Epoch : 661, ELBO : -637.377308 (0s), Perplexity : 727.153137
# Epoch : 662, ELBO : -633.833635 (0s), Perplexity : 728.477478
# Epoch : 663, ELBO : -637.817330 (0s), Perplexity : 728.355225
# Epoch : 664, ELBO : -637.170577 (0s), Perplexity : 728.517090
# Epoch : 665, ELBO : -633.856601 (0s), Perplexity : 727.915649
# Epoch : 666, ELBO : -636.217676 (0s), Perplexity : 727.245361
# Epoch : 667, ELBO : -634.535750 (0s), Perplexity : 726.412903
# Epoch : 668, ELBO : -637.299930 (0s), Perplexity : 725.816650
# Epoch : 669, ELBO : -634.685569 (0s), Perplexity : 725.355469
# Epoch : 670, ELBO : -633.469527 (0s), Perplexity : 725.191162
# Epoch : 671, ELBO : -635.264113 (0s), Perplexity : 725.229553
# Epoch : 672, ELBO : -633.635315 (0s), Perplexity : 725.236816
# Epoch : 673, ELBO : -634.304984 (0s), Perplexity : 724.246704
# Epoch : 674, ELBO : -634.267320 (0s), Perplexity : 725.529114
# Epoch : 675, ELBO : -637.457819 (0s), Perplexity : 723.827942
# Epoch : 676, ELBO : -637.777485 (0s), Perplexity : 725.114441
# Epoch : 677, ELBO : -635.854842 (0s), Perplexity : 726.190857
# Epoch : 678, ELBO : -637.454226 (0s), Perplexity : 723.580200
# Epoch : 679, ELBO : -638.572457 (0s), Perplexity : 723.212463
# Epoch : 680, ELBO : -632.964475 (0s), Perplexity : 723.562927
# Epoch : 681, ELBO : -635.128834 (0s), Perplexity : 722.977661
# Epoch : 682, ELBO : -634.176711 (0s), Perplexity : 722.326355
# Epoch : 683, ELBO : -634.288960 (0s), Perplexity : 722.039185
# Epoch : 684, ELBO : -635.868962 (0s), Perplexity : 720.721375
# Epoch : 685, ELBO : -636.767009 (0s), Perplexity : 721.041748
# Epoch : 686, ELBO : -634.067877 (0s), Perplexity : 721.268738
# Epoch : 687, ELBO : -635.191587 (0s), Perplexity : 721.342651
# Epoch : 688, ELBO : -632.183186 (0s), Perplexity : 721.043457
# Epoch : 689, ELBO : -635.322468 (0s), Perplexity : 720.442078
# Epoch : 690, ELBO : -634.367545 (0s), Perplexity : 720.524841
# Epoch : 691, ELBO : -632.972579 (0s), Perplexity : 719.612915
# Epoch : 692, ELBO : -636.128437 (0s), Perplexity : 719.397461
# Epoch : 693, ELBO : -634.723680 (0s), Perplexity : 719.534302
# Epoch : 694, ELBO : -633.717668 (0s), Perplexity : 718.576660
# Epoch : 695, ELBO : -635.270355 (0s), Perplexity : 718.937256
# Epoch : 696, ELBO : -635.856504 (0s), Perplexity : 718.842590
# Epoch : 697, ELBO : -634.555398 (0s), Perplexity : 719.021912
# Epoch : 698, ELBO : -634.912129 (0s), Perplexity : 718.725769
# Epoch : 699, ELBO : -633.418857 (0s), Perplexity : 719.169006
# Epoch : 700, ELBO : -636.524619 (0s), Perplexity : 717.344238
# Epoch : 701, ELBO : -633.583044 (0s), Perplexity : 718.125183
# Epoch : 702, ELBO : -635.825975 (0s), Perplexity : 716.638916
# Epoch : 703, ELBO : -630.989302 (0s), Perplexity : 716.777649
# Epoch : 704, ELBO : -634.305054 (0s), Perplexity : 717.461914
# Epoch : 705, ELBO : -633.892514 (0s), Perplexity : 715.567383
# Epoch : 706, ELBO : -632.523671 (0s), Perplexity : 716.275757
# Epoch : 707, ELBO : -635.948267 (0s), Perplexity : 713.963135
# Epoch : 708, ELBO : -634.381939 (0s), Perplexity : 713.985901
# Epoch : 709, ELBO : -629.571131 (0s), Perplexity : 715.298218
# Epoch : 710, ELBO : -633.893294 (0s), Perplexity : 714.825317
# Epoch : 711, ELBO : -634.558264 (0s), Perplexity : 713.348511
# Epoch : 712, ELBO : -635.455983 (0s), Perplexity : 714.056763
# Epoch : 713, ELBO : -636.123274 (0s), Perplexity : 713.938232
# Epoch : 714, ELBO : -633.413760 (0s), Perplexity : 713.311462
# Epoch : 715, ELBO : -629.039106 (0s), Perplexity : 712.153198
# Epoch : 716, ELBO : -633.159615 (0s), Perplexity : 712.731750
# Epoch : 717, ELBO : -633.048534 (0s), Perplexity : 713.195801
# Epoch : 718, ELBO : -634.581970 (0s), Perplexity : 713.018677
# Epoch : 719, ELBO : -634.054188 (0s), Perplexity : 711.959717
# Epoch : 720, ELBO : -632.821714 (0s), Perplexity : 712.033020
# Epoch : 721, ELBO : -630.279663 (0s), Perplexity : 711.376709
# Epoch : 722, ELBO : -633.838999 (0s), Perplexity : 711.316284
# Epoch : 723, ELBO : -632.623177 (0s), Perplexity : 710.334717
# Epoch : 724, ELBO : -636.205020 (0s), Perplexity : 710.356079
# Epoch : 725, ELBO : -629.996421 (0s), Perplexity : 712.474548
# Epoch : 726, ELBO : -632.683211 (0s), Perplexity : 711.357666
# Epoch : 727, ELBO : -631.239369 (0s), Perplexity : 711.543579
# Epoch : 728, ELBO : -632.736506 (0s), Perplexity : 711.501221
# Epoch : 729, ELBO : -633.545366 (0s), Perplexity : 709.967957
# Epoch : 730, ELBO : -635.033067 (0s), Perplexity : 710.496643
# Epoch : 731, ELBO : -635.011907 (0s), Perplexity : 707.888000
# Epoch : 732, ELBO : -633.504883 (0s), Perplexity : 708.282349
# Epoch : 733, ELBO : -634.972853 (0s), Perplexity : 707.097595
# Epoch : 734, ELBO : -632.338407 (0s), Perplexity : 707.376465
# Epoch : 735, ELBO : -633.445351 (0s), Perplexity : 707.445312
# Epoch : 736, ELBO : -634.328297 (0s), Perplexity : 707.150879
# Epoch : 737, ELBO : -630.830253 (0s), Perplexity : 706.693115
# Epoch : 738, ELBO : -632.089908 (0s), Perplexity : 706.665100
# Epoch : 739, ELBO : -631.576918 (0s), Perplexity : 707.477356
# Epoch : 740, ELBO : -632.640456 (0s), Perplexity : 707.460449
# Epoch : 741, ELBO : -633.671578 (0s), Perplexity : 706.162231
# Epoch : 742, ELBO : -632.694258 (0s), Perplexity : 706.129211
# Epoch : 743, ELBO : -632.667775 (0s), Perplexity : 705.564087
# Epoch : 744, ELBO : -633.355890 (0s), Perplexity : 706.410095
# Epoch : 745, ELBO : -629.871352 (0s), Perplexity : 706.688721
# Epoch : 746, ELBO : -634.079579 (0s), Perplexity : 705.709106
# Epoch : 747, ELBO : -630.330344 (0s), Perplexity : 704.955078
# Epoch : 748, ELBO : -634.056979 (0s), Perplexity : 705.690308
# Epoch : 749, ELBO : -632.239943 (0s), Perplexity : 705.578552
# Epoch : 750, ELBO : -633.233324 (0s), Perplexity : 703.333374
# Epoch : 751, ELBO : -630.951280 (0s), Perplexity : 704.157532
# Epoch : 752, ELBO : -630.333540 (0s), Perplexity : 703.997009
# Epoch : 753, ELBO : -634.702978 (0s), Perplexity : 703.029541
# Epoch : 754, ELBO : -632.239299 (0s), Perplexity : 701.697266
# Epoch : 755, ELBO : -634.910342 (0s), Perplexity : 701.211609
# Epoch : 756, ELBO : -628.270039 (0s), Perplexity : 703.270325
# Epoch : 757, ELBO : -631.369077 (0s), Perplexity : 700.751343
# Epoch : 758, ELBO : -630.591428 (0s), Perplexity : 703.717102
# Epoch : 759, ELBO : -634.194862 (0s), Perplexity : 702.160828
# Epoch : 760, ELBO : -632.453891 (0s), Perplexity : 700.881348
# Epoch : 761, ELBO : -633.799192 (0s), Perplexity : 702.411682
# Epoch : 762, ELBO : -630.681546 (0s), Perplexity : 700.037659
# Epoch : 763, ELBO : -633.208002 (0s), Perplexity : 700.265320
# Epoch : 764, ELBO : -632.982882 (0s), Perplexity : 701.733093
# Epoch : 765, ELBO : -632.598175 (0s), Perplexity : 700.862305
# Epoch : 766, ELBO : -632.228951 (0s), Perplexity : 698.257385
# Epoch : 767, ELBO : -632.745852 (0s), Perplexity : 698.929321
# Epoch : 768, ELBO : -631.017647 (0s), Perplexity : 698.688721
# Epoch : 769, ELBO : -632.174133 (0s), Perplexity : 700.270691
# Epoch : 770, ELBO : -631.823317 (0s), Perplexity : 699.115295
# Epoch : 771, ELBO : -626.946866 (0s), Perplexity : 698.156189
# Epoch : 772, ELBO : -628.239152 (0s), Perplexity : 698.943298
# Epoch : 773, ELBO : -629.700328 (0s), Perplexity : 698.019348
# Epoch : 774, ELBO : -631.603255 (0s), Perplexity : 696.349854
# Epoch : 775, ELBO : -634.068556 (0s), Perplexity : 697.905884
# Epoch : 776, ELBO : -630.735260 (0s), Perplexity : 697.941467
# Epoch : 777, ELBO : -633.263317 (0s), Perplexity : 696.951416
# Epoch : 778, ELBO : -631.968059 (0s), Perplexity : 696.233643
# Epoch : 779, ELBO : -627.970767 (0s), Perplexity : 696.194458
# Epoch : 780, ELBO : -632.593947 (0s), Perplexity : 696.532837
# Epoch : 781, ELBO : -631.864827 (0s), Perplexity : 695.496704
# Epoch : 782, ELBO : -631.464048 (0s), Perplexity : 695.605469
# Epoch : 783, ELBO : -628.984808 (0s), Perplexity : 696.047058
# Epoch : 784, ELBO : -631.099437 (0s), Perplexity : 694.804565
# Epoch : 785, ELBO : -629.532687 (0s), Perplexity : 693.932434
# Epoch : 786, ELBO : -630.266801 (0s), Perplexity : 695.461182
# Epoch : 787, ELBO : -628.248693 (0s), Perplexity : 695.354431
# Epoch : 788, ELBO : -629.875039 (0s), Perplexity : 694.784668
# Epoch : 789, ELBO : -630.538283 (0s), Perplexity : 694.652161
# Epoch : 790, ELBO : -632.457281 (0s), Perplexity : 693.303040
# Epoch : 791, ELBO : -630.696838 (0s), Perplexity : 694.854248
# Epoch : 792, ELBO : -631.215596 (0s), Perplexity : 692.301086
# Epoch : 793, ELBO : -629.808766 (0s), Perplexity : 692.944092
# Epoch : 794, ELBO : -629.857527 (0s), Perplexity : 692.904114
# Epoch : 795, ELBO : -630.656225 (0s), Perplexity : 692.985413
# Epoch : 796, ELBO : -627.785689 (0s), Perplexity : 691.873047
# Epoch : 797, ELBO : -632.006353 (0s), Perplexity : 692.877380
# Epoch : 798, ELBO : -633.238636 (0s), Perplexity : 692.449341
# Epoch : 799, ELBO : -632.151148 (0s), Perplexity : 690.959167
# Epoch : 800, ELBO : -626.832943 (0s), Perplexity : 691.244507
# Epoch : 801, ELBO : -630.537040 (0s), Perplexity : 690.390686
# Epoch : 802, ELBO : -626.121135 (0s), Perplexity : 690.940674
# Epoch : 803, ELBO : -630.909990 (0s), Perplexity : 690.224487
# Epoch : 804, ELBO : -628.610008 (0s), Perplexity : 690.168518
# Epoch : 805, ELBO : -630.963769 (0s), Perplexity : 690.829346
# Epoch : 806, ELBO : -630.941004 (0s), Perplexity : 689.643494
# Epoch : 807, ELBO : -627.995334 (0s), Perplexity : 691.285706
# Epoch : 808, ELBO : -634.611256 (0s), Perplexity : 690.200134
# Epoch : 809, ELBO : -632.918096 (0s), Perplexity : 688.941772
# Epoch : 810, ELBO : -631.222065 (0s), Perplexity : 689.389648
# Epoch : 811, ELBO : -631.002078 (0s), Perplexity : 689.395569
# Epoch : 812, ELBO : -627.978441 (0s), Perplexity : 687.804077
# Epoch : 813, ELBO : -631.466998 (0s), Perplexity : 687.669922
# Epoch : 814, ELBO : -630.110445 (0s), Perplexity : 687.617126
# Epoch : 815, ELBO : -626.522741 (0s), Perplexity : 687.015076
# Epoch : 816, ELBO : -631.775721 (0s), Perplexity : 687.009216
# Epoch : 817, ELBO : -630.333943 (0s), Perplexity : 686.739624
# Epoch : 818, ELBO : -631.185336 (0s), Perplexity : 687.716187
# Epoch : 819, ELBO : -630.928858 (0s), Perplexity : 686.403442
# Epoch : 820, ELBO : -628.112762 (0s), Perplexity : 686.882446
# Epoch : 821, ELBO : -629.983790 (0s), Perplexity : 686.442688
# Epoch : 822, ELBO : -627.188729 (0s), Perplexity : 686.274475
# Epoch : 823, ELBO : -630.880737 (0s), Perplexity : 685.036011
# Epoch : 824, ELBO : -626.948639 (0s), Perplexity : 685.459778
# Epoch : 825, ELBO : -630.898216 (0s), Perplexity : 686.617493
# Epoch : 826, ELBO : -629.495800 (0s), Perplexity : 684.422852
# Epoch : 827, ELBO : -631.034421 (0s), Perplexity : 684.939331
# Epoch : 828, ELBO : -628.466556 (0s), Perplexity : 684.319702
# Epoch : 829, ELBO : -627.696381 (0s), Perplexity : 683.828491
# Epoch : 830, ELBO : -625.727816 (0s), Perplexity : 684.156921
# Epoch : 831, ELBO : -630.152222 (0s), Perplexity : 683.914551
# Epoch : 832, ELBO : -622.874487 (0s), Perplexity : 684.404907
# Epoch : 833, ELBO : -627.774694 (0s), Perplexity : 683.489075
# Epoch : 834, ELBO : -629.960929 (0s), Perplexity : 682.780945
# Epoch : 835, ELBO : -626.360402 (0s), Perplexity : 683.510620
# Epoch : 836, ELBO : -629.255682 (0s), Perplexity : 682.822937
# Epoch : 837, ELBO : -629.741197 (0s), Perplexity : 683.489075
# Epoch : 838, ELBO : -630.876040 (0s), Perplexity : 683.025146
# Epoch : 839, ELBO : -629.255438 (0s), Perplexity : 683.566650
# Epoch : 840, ELBO : -627.001469 (0s), Perplexity : 681.580322
# Epoch : 841, ELBO : -626.231021 (0s), Perplexity : 680.273071
# Epoch : 842, ELBO : -629.510473 (0s), Perplexity : 681.439880
# Epoch : 843, ELBO : -630.634558 (0s), Perplexity : 681.756775
# Epoch : 844, ELBO : -630.186615 (0s), Perplexity : 681.565674
# Epoch : 845, ELBO : -628.421168 (0s), Perplexity : 682.069580
# Epoch : 846, ELBO : -624.166398 (0s), Perplexity : 681.943726
# Epoch : 847, ELBO : -631.199990 (0s), Perplexity : 679.981873
# Epoch : 848, ELBO : -630.242136 (0s), Perplexity : 681.044922
# Epoch : 849, ELBO : -627.031064 (0s), Perplexity : 679.782776
# Epoch : 850, ELBO : -628.446641 (0s), Perplexity : 680.982239
# Epoch : 851, ELBO : -628.073861 (0s), Perplexity : 679.624329
# Epoch : 852, ELBO : -628.023196 (0s), Perplexity : 679.292542
# Epoch : 853, ELBO : -627.913241 (0s), Perplexity : 678.212158
# Epoch : 854, ELBO : -627.706793 (0s), Perplexity : 678.942810
# Epoch : 855, ELBO : -631.403673 (0s), Perplexity : 678.470337
# Epoch : 856, ELBO : -628.256173 (0s), Perplexity : 678.680298
# Epoch : 857, ELBO : -626.795088 (0s), Perplexity : 678.326355
# Epoch : 858, ELBO : -629.896659 (0s), Perplexity : 678.531128
# Epoch : 859, ELBO : -630.107228 (0s), Perplexity : 677.697876
# Epoch : 860, ELBO : -631.569613 (0s), Perplexity : 677.516907
# Epoch : 861, ELBO : -630.506162 (0s), Perplexity : 676.287476
# Epoch : 862, ELBO : -629.885051 (0s), Perplexity : 677.354736
# Epoch : 863, ELBO : -629.011472 (0s), Perplexity : 676.846558
# Epoch : 864, ELBO : -624.518707 (0s), Perplexity : 676.759094
# Epoch : 865, ELBO : -628.868358 (0s), Perplexity : 676.702332
# Epoch : 866, ELBO : -629.685852 (0s), Perplexity : 677.383179
# Epoch : 867, ELBO : -631.001912 (0s), Perplexity : 676.133362
# Epoch : 868, ELBO : -627.202787 (0s), Perplexity : 675.243103
# Epoch : 869, ELBO : -627.920258 (0s), Perplexity : 676.336182
# Epoch : 870, ELBO : -627.813094 (0s), Perplexity : 676.010864
# Epoch : 871, ELBO : -625.387826 (0s), Perplexity : 674.849792
# Epoch : 872, ELBO : -629.746862 (0s), Perplexity : 674.540588
# Epoch : 873, ELBO : -629.355724 (0s), Perplexity : 674.735229
# Epoch : 874, ELBO : -625.427937 (0s), Perplexity : 673.568359
# Epoch : 875, ELBO : -628.532965 (0s), Perplexity : 674.617188
# Epoch : 876, ELBO : -629.756645 (0s), Perplexity : 673.877686
# Epoch : 877, ELBO : -630.000674 (0s), Perplexity : 674.573120
# Epoch : 878, ELBO : -630.028786 (0s), Perplexity : 674.505554
# Epoch : 879, ELBO : -626.333374 (0s), Perplexity : 673.843323
# Epoch : 880, ELBO : -629.685669 (0s), Perplexity : 673.266479
# Epoch : 881, ELBO : -628.415430 (0s), Perplexity : 672.221375
# Epoch : 882, ELBO : -628.270125 (0s), Perplexity : 673.766235
# Epoch : 883, ELBO : -628.636572 (0s), Perplexity : 670.721313
# Epoch : 884, ELBO : -629.029147 (0s), Perplexity : 672.281616
# Epoch : 885, ELBO : -628.529197 (0s), Perplexity : 672.845398
# Epoch : 886, ELBO : -627.094299 (0s), Perplexity : 671.453125
# Epoch : 887, ELBO : -627.392473 (0s), Perplexity : 670.921204
# Epoch : 888, ELBO : -629.314694 (0s), Perplexity : 672.367554
# Epoch : 889, ELBO : -628.656749 (0s), Perplexity : 670.629211
# Epoch : 890, ELBO : -628.151339 (0s), Perplexity : 672.210144
# Epoch : 891, ELBO : -624.899492 (0s), Perplexity : 670.631104
# Epoch : 892, ELBO : -628.724526 (0s), Perplexity : 670.207886
# Epoch : 893, ELBO : -624.213052 (0s), Perplexity : 670.997681
# Epoch : 894, ELBO : -624.932079 (0s), Perplexity : 670.667908
# Epoch : 895, ELBO : -627.761513 (0s), Perplexity : 670.127014
# Epoch : 896, ELBO : -626.989280 (0s), Perplexity : 670.966003
# Epoch : 897, ELBO : -629.339924 (0s), Perplexity : 669.847473
# Epoch : 898, ELBO : -626.069569 (0s), Perplexity : 670.073975
# Epoch : 899, ELBO : -618.769348 (0s), Perplexity : 670.482422
# Epoch : 900, ELBO : -628.122056 (0s), Perplexity : 669.217590
# Epoch : 901, ELBO : -630.215895 (0s), Perplexity : 668.816589
# Epoch : 902, ELBO : -627.461093 (0s), Perplexity : 668.375000
# Epoch : 903, ELBO : -628.162653 (0s), Perplexity : 667.700378
# Epoch : 904, ELBO : -630.827276 (0s), Perplexity : 667.759888
# Epoch : 905, ELBO : -624.824044 (0s), Perplexity : 668.718384
# Epoch : 906, ELBO : -623.149209 (0s), Perplexity : 668.952759
# Epoch : 907, ELBO : -626.276031 (0s), Perplexity : 667.664062
# Epoch : 908, ELBO : -626.699366 (0s), Perplexity : 667.850647
# Epoch : 909, ELBO : -627.929366 (0s), Perplexity : 667.811157
# Epoch : 910, ELBO : -627.059232 (0s), Perplexity : 665.590576
# Epoch : 911, ELBO : -627.497018 (0s), Perplexity : 667.587341
# Epoch : 912, ELBO : -628.763400 (0s), Perplexity : 666.011841
# Epoch : 913, ELBO : -628.515536 (0s), Perplexity : 667.542419
# Epoch : 914, ELBO : -629.388497 (0s), Perplexity : 666.869873
# Epoch : 915, ELBO : -623.691151 (0s), Perplexity : 665.549011
# Epoch : 916, ELBO : -627.437084 (0s), Perplexity : 664.826416
# Epoch : 917, ELBO : -626.592982 (0s), Perplexity : 667.687927
# Epoch : 918, ELBO : -627.331802 (0s), Perplexity : 665.481750
# Epoch : 919, ELBO : -623.863645 (0s), Perplexity : 665.975342
# Epoch : 920, ELBO : -628.534915 (0s), Perplexity : 664.950073
# Epoch : 921, ELBO : -626.623366 (0s), Perplexity : 666.065857
# Epoch : 922, ELBO : -625.478086 (0s), Perplexity : 666.462341
# Epoch : 923, ELBO : -626.174910 (0s), Perplexity : 663.939087
# Epoch : 924, ELBO : -628.384288 (0s), Perplexity : 664.354553
# Epoch : 925, ELBO : -627.239541 (0s), Perplexity : 664.890808
# Epoch : 926, ELBO : -624.152924 (0s), Perplexity : 664.538025
# Epoch : 927, ELBO : -626.730696 (0s), Perplexity : 664.067627
# Epoch : 928, ELBO : -626.714086 (0s), Perplexity : 663.223022
# Epoch : 929, ELBO : -624.394476 (0s), Perplexity : 662.298645
# Epoch : 930, ELBO : -628.245044 (0s), Perplexity : 662.400635
# Epoch : 931, ELBO : -624.501620 (0s), Perplexity : 663.066162
# Epoch : 932, ELBO : -626.174355 (0s), Perplexity : 663.649780
# Epoch : 933, ELBO : -628.078380 (0s), Perplexity : 663.258423
# Epoch : 934, ELBO : -627.043632 (0s), Perplexity : 662.665710
# Epoch : 935, ELBO : -623.292056 (0s), Perplexity : 661.874939
# Epoch : 936, ELBO : -628.623624 (0s), Perplexity : 662.715027
# Epoch : 937, ELBO : -627.867101 (0s), Perplexity : 661.505493
# Epoch : 938, ELBO : -625.293593 (0s), Perplexity : 661.737671
# Epoch : 939, ELBO : -627.762859 (0s), Perplexity : 662.154663
# Epoch : 940, ELBO : -628.571711 (0s), Perplexity : 661.203064
# Epoch : 941, ELBO : -622.647333 (0s), Perplexity : 661.379944
# Epoch : 942, ELBO : -627.683186 (0s), Perplexity : 660.207825
# Epoch : 943, ELBO : -626.690308 (0s), Perplexity : 661.813721
# Epoch : 944, ELBO : -628.886400 (0s), Perplexity : 660.523987
# Epoch : 945, ELBO : -624.303286 (0s), Perplexity : 660.171631
# Epoch : 946, ELBO : -625.857774 (0s), Perplexity : 659.470947
# Epoch : 947, ELBO : -628.147453 (0s), Perplexity : 660.556091
# Epoch : 948, ELBO : -624.637756 (0s), Perplexity : 660.751709
# Epoch : 949, ELBO : -626.506278 (0s), Perplexity : 659.623169
# Epoch : 950, ELBO : -627.516016 (0s), Perplexity : 661.072876
# Epoch : 951, ELBO : -624.952573 (0s), Perplexity : 660.388245
# Epoch : 952, ELBO : -627.562600 (0s), Perplexity : 659.510864
# Epoch : 953, ELBO : -626.054310 (0s), Perplexity : 658.135193
# Epoch : 954, ELBO : -626.577161 (0s), Perplexity : 659.354004
# Epoch : 955, ELBO : -624.690242 (0s), Perplexity : 660.281494
# Epoch : 956, ELBO : -625.295568 (0s), Perplexity : 658.920837
# Epoch : 957, ELBO : -625.382058 (0s), Perplexity : 657.693481
# Epoch : 958, ELBO : -627.444047 (0s), Perplexity : 657.215088
# Epoch : 959, ELBO : -625.479029 (0s), Perplexity : 657.894897
# Epoch : 960, ELBO : -624.318631 (0s), Perplexity : 657.847839
# Epoch : 961, ELBO : -626.641427 (0s), Perplexity : 657.987122
# Epoch : 962, ELBO : -627.026950 (0s), Perplexity : 658.505005
# Epoch : 963, ELBO : -627.225417 (0s), Perplexity : 656.867310
# Epoch : 964, ELBO : -624.305267 (0s), Perplexity : 658.022888
# Epoch : 965, ELBO : -624.978055 (0s), Perplexity : 656.623047
# Epoch : 966, ELBO : -625.114764 (0s), Perplexity : 656.782471
# Epoch : 967, ELBO : -625.547924 (0s), Perplexity : 657.452087
# Epoch : 968, ELBO : -621.472332 (0s), Perplexity : 657.180969
# Epoch : 969, ELBO : -627.480752 (0s), Perplexity : 656.954712
# Epoch : 970, ELBO : -623.218106 (0s), Perplexity : 656.683167
# Epoch : 971, ELBO : -623.636919 (0s), Perplexity : 655.909241
# Epoch : 972, ELBO : -625.110666 (0s), Perplexity : 656.401123
# Epoch : 973, ELBO : -624.408850 (0s), Perplexity : 655.590332
# Epoch : 974, ELBO : -626.959736 (0s), Perplexity : 655.511230
# Epoch : 975, ELBO : -624.956279 (0s), Perplexity : 654.636963
# Epoch : 976, ELBO : -624.255726 (0s), Perplexity : 655.323120
# Epoch : 977, ELBO : -623.754106 (0s), Perplexity : 655.132812
# Epoch : 978, ELBO : -622.511633 (0s), Perplexity : 654.608215
# Epoch : 979, ELBO : -623.447230 (0s), Perplexity : 654.394470
# Epoch : 980, ELBO : -625.657354 (0s), Perplexity : 653.685547
# Epoch : 981, ELBO : -622.979722 (0s), Perplexity : 654.732178
# Epoch : 982, ELBO : -624.325772 (0s), Perplexity : 652.977783
# Epoch : 983, ELBO : -624.190560 (0s), Perplexity : 653.117554
# Epoch : 984, ELBO : -623.801491 (0s), Perplexity : 653.131287
# Epoch : 985, ELBO : -626.785700 (0s), Perplexity : 653.355835
# Epoch : 986, ELBO : -624.508331 (0s), Perplexity : 653.380188
# Epoch : 987, ELBO : -624.281358 (0s), Perplexity : 652.831726
# Epoch : 988, ELBO : -624.232824 (0s), Perplexity : 651.716675
# Epoch : 989, ELBO : -623.942974 (0s), Perplexity : 653.019470
# Epoch : 990, ELBO : -625.175959 (0s), Perplexity : 653.052490
# Epoch : 991, ELBO : -626.581684 (0s), Perplexity : 651.959778
# Epoch : 992, ELBO : -625.928678 (0s), Perplexity : 652.783508
# Epoch : 993, ELBO : -625.675462 (0s), Perplexity : 651.504150
# Epoch : 994, ELBO : -625.900588 (0s), Perplexity : 651.830444
# Epoch : 995, ELBO : -625.930137 (0s), Perplexity : 651.630920
# Epoch : 996, ELBO : -625.954853 (0s), Perplexity : 650.430786
# Epoch : 997, ELBO : -622.600239 (0s), Perplexity : 650.799072
# Epoch : 998, ELBO : -621.261783 (0s), Perplexity : 650.794678
# Epoch : 999, ELBO : -625.108340 (0s), Perplexity : 651.503235
# Epoch : 1000, ELBO : -622.772050 (0s), Perplexity : 650.333130

# %%
dec.para
# Out:
# -78876
